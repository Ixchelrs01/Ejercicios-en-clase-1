# %% [markdown]
# <a href="https://colab.research.google.com/github/Ixchelrs01/01_04_EjercicioAngulo/blob/main/Caminata_aleatoria-varias-particulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
#
#

import random
from matplotlib import pyplot
import matplotlib.pyplot as plt

def movimientoX():
  deltaX= random.randint(-100,100)
  return deltaX/100

def movimientoY():
  deltaY= random.randint(-100,100)
  return deltaY/100

print(movimientoX() ,movimientoY())


desplazamientoX=[]
desplazamientoY=[]

Xinicial=0
Yinicial=0
counter= 0
desplazamientoX.append(Xinicial)
desplazamientoY.append(Yinicial)
x=Xinicial
y=Yinicial

NumerodeIteracion= int (input("numero de iteraciones"))


while counter<NumerodeIteracion:
  x+= movimientoX()
  y+= movimientoY()
  desplazamientoX.append(x)
  desplazamientoY.append(y)
  counter+=1

plt.plot(desplazamientoX, desplazamientoY)
plt.plot(x,y,marker="o",color="m", label="Punto final")
plt.plot(Xinicial,Yinicial,marker="o",color="r",label="Punto inicial")
plt.show()
# Out:
# -0.19 0.42
# numero de iteraciones10000

# %%
import random
from matplotlib import pyplot
import matplotlib.pyplot as plt

def movimientoX():
  deltaX= random.randint(-100,100)
  return deltaX/100

def movimientoY():
  deltaY= random.randint(-100,100)
  return deltaY/100

print(movimientoX() ,movimientoY())


#desplazamientoX.append(Xinicial)
#desplazamientoY.append(Yinicial)
partes=0

NumerodeIteracion= int (input("¿Cuántas iteraciones desea realizar?"))
NumerodeParticulas=int (input("¿cuántas particulas deseas simular?"))
partes=0


while partes<NumerodeParticulas:
  desplazamientoX=[]
  desplazamientoY=[]
  Xinicial= movimientoX()
  Yinicial= movimientoY()
  x=Xinicial
  y=Yinicial
  counter= 0
  while counter<NumerodeIteracion:
    x+= movimientoX()
    y+= movimientoY()
    desplazamientoX.append(x)
    desplazamientoY.append(y)
    counter+=1
  partes+=1
  plt.plot(desplazamientoX, desplazamientoY)

plt.plot(x,y,marker="o",color="m", label="Punto final")
plt.plot(Xinicial,Yinicial,marker="o",color="r",label="Punto inicial")
plt.show()
# Out:
# 0.13 0.87
# ¿Cuántas iteraciones desea realizar?100
# ¿cuántas particulas deseas simular?5

# %%
import random
from matplotlib import pyplot
import matplotlib.pyplot as plt

def movimientoX():
  deltaX= random.randint(-100,100)
  return deltaX/100

def movimientoY():
  deltaY= random.randint(-100,100)
  return deltaY/100

print(movimientoX() ,movimientoY())


#desplazamientoX.append(Xinicial)
#desplazamientoY.append(Yinicial)
partes=0

NumerodeIteracion= int (input("¿Cuántas iteraciones desea realizar?"))
NumerodeParticulas=int (input("¿cuántas particulas deseas simular?"))
partes=0


while partes<NumerodeParticulas:
  desplazamientoX=[]
  desplazamientoY=[]
  Xinicial= movimientoX()
  Yinicial= movimientoY()
  x=Xinicial
  y=Yinicial
  counter= 0
  while counter<NumerodeIteracion:
    x+= movimientoX()
    y+= movimientoY()
    desplazamientoX.append(x)
    desplazamientoY.append(y)
    counter+=1
  partes+=1
  plt.plot(desplazamientoX, desplazamientoY)
  plt.plot(x,y,marker="o",color="m", label="Punto final")
  plt.plot(Xinicial,Yinicial,marker="o",color="r",label="Punto inicial")
  plt.show()
# Out:
# 0.66 -0.92
# ¿Cuántas iteraciones desea realizar?100
# ¿cuántas particulas deseas simular?5
