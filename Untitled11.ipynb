# %% [markdown]
# <a href="https://colab.research.google.com/github/Ixchelrs01/01_04_EjercicioAngulo/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Grafico del oscilador armonico
#autor: Ixchel Ramirez Solano
#fecha: Agosto 30, 2021

#importar librerias
import math
import matplotlib.pyplot as plt
import numpy as np

#Definir las funciones
def f1(A,T,t1):
       return A*np.sin(np.pi*2/T*t1)

t1=np.arange(0,10,.1)

def f2(A,f1):
    return A*f1


A=float(input("Dame una amplitud (A): "))
T=float(input("Dame un periodo(T): "))
print("Grafica de y=Asen(wt)")

plt.plot(t1,f1(A,T,t1))
plt.grid(color='r', linestyle="-", linewidth=2)
plt.show()
# Out:
# Dame una amplitud (A): 5
# Dame un periodo(T): 2
# Grafica de y=Asen(wt)
